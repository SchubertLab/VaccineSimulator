# %% [markdown]
# # Run Script
# This is the notebook to run the vaccineSimulator more efficiently and clearly. TODO adapt and finish the methods

# %%
from src import vaccineSim
import pandas as pd
import numpy as np
import scanpy as sc

# %%
adata = sc.read_h5ad('/Users/juliakuhn/Desktop/uni/WS2425/Cmscb/Project_phase/VaccineSimulator/02_dex_annotated_cd8.h5ad')

# %%
results=vaccineSim.run(adata = adata, 
                embedding_method = "pca", 
                clone_pairing_method = "time_point",
                split = "timepoint",
                model = "linear_regression",
                outcome_variable = "IFN_Score")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 results=vaccineSim.run(adata = adata,
#       2                 embedding_method = "pca",
#       3                 clone_pairing_method = "time_point",
#       4                 split = "timepoint",
#       5                 model = "linear_regression",
#       6                 outcome_variable = "IFN_Score")
#
# File ~/Desktop/uni/WS2425/Cmscb/Project_phase/VaccineSimulator/src/vaccineSim.py:77, in run.__init__(self, adata, embedding_method, outcome_variable, clone_pairing_method, split, model)
#      75 # eval results
#      76 evaluation = eval.eval()
# ---> 77 evaluation.eval(data)
#
# File ~/Desktop/uni/WS2425/Cmscb/Project_phase/VaccineSimulator/src/eval.py:31, in eval.eval(self, data)
#      27 self.y_t1_test = data.y_t1_test
#      28 self.y_t1_pred = data.y_t1_pred_aggregated
# ---> 31 mse_s1 = mean_squared_error(self.y_s1_test, self.y_s1_pred_aggregated)
#      32 mse_s1 = mse_clonotype(self.y_s1_test, self.y_s1_pred_aggregated)
#      33 recall_ks1 = self.recall_at_k_clonotype(
#      34     self.y_s1_test,
#      35     self.y_s1_pred_aggregated,
#      36     k
#      37 )
#
# AttributeError: 'eval' object has no attribute 'y_s1_pred_aggregated'

# %%
"""results=vaccineSim.run(adata = adata, 
                embedding_method = "pca", 
                clone_pairing_method = "time_point",
                split = "timepoint",
                model = "linear_regression",
                outcome_variable = "IFN_Score")"""
